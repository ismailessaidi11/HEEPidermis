# %% [markdown]
# ![grafik.png](attachment:ee9bc81a-10e8-4eb8-b5c4-2aee3f60d52d.png)

# %% [markdown]
# ![grafik.png](attachment:6ad10e55-7c49-4002-8155-607674398441.png)

# %%
import eseries

R1 = eseries.find_nearest(eseries.E48, 68000)
R2 = eseries.find_nearest(eseries.E48, 39000)


SUM_R = R1 + R2
factor=-1.186
VOUT = factor*(1+R1/R2)
Ideal_ratio = -3.3/factor -1
DS_value_R1plusR2 = 100000
print("Ideal R Ratio={}".format(Ideal_ratio))
print("R1={}, R2={}, VOUT={}".format(R1,R2,VOUT))
print("Datasheet value for R1+R2 ={}".format(DS_value_R1plusR2))
print("Current R1+R2={}".format(SUM_R))
# Out:
# Ideal R Ratio=1.7824620573355818
# R1=68100.0, R2=38300.0, VOUT=-3.2947885117493465
# Datasheet value for R1+R2 =100000
# Current R1+R2=106400.0
